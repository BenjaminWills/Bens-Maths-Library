# %%
from Mathematics_fundamentals.linear_algebra.linear_algebra import Vector
from Mathematics_fundamentals.multivariable_calculus.mvc import MVC

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('/Users/benwills/Desktop/personal_projects/applications/train.csv')

# %%
import numpy as np
s = np.linspace(0,100,10000)

# %%
plt.figure(figsize=(18, 7))

plt.scatter(train.iloc[:, 0], train.iloc[:, -1])
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(s,1.014316975196076*s -0.4609177540791851 )
plt.show()

# %%
training_data_dict = train.to_dict()

# %%
training_data_list = [[training_data_dict['x'][i],training_data_dict['y'][i]] for i in range(200)]

# %%
training_data_list[0][1]
# Out:
# 21.54945196
